# %%
pip install panda
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.  Building wheel for panda (setup.py): finished with status 'done'
#
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7261 sha256=e493adc6e2a1eb7ec11389c088dc4b68516ad27ec58505de54e9fdcc5c3f8265
#   Stored in directory: c:\users\vivek\appdata\local\pip\cache\wheels\e9\b8\cc\e2f18ad77320b551f1b7435014844a9cc3e9d6185cb93a3a31
# Successfully built panda
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = pd.read_csv('cars.csv')
data.head(20)
# Out:
#     Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                 140                143               202
# 1                 140                143               202
# 2                 140                143               202
# 3                 140                143               202
# 4                 140                143               202
# 5                  91                 17                62
# 6                  91                 17                62
# 7                 201                221               191
# 8                 201                221               191
# 9                 147                 96                34
# 10                147                 96                34
# 11                147                 96                34
# 12                172                 63                87
# 13                172                 63                87
# 14                226                243               201
# ...

# %%
data['Identification.Make'].value_counts().plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np

# %%
time_series = pd.date_range('1/1/2020', periods=20)

df = pd.DataFrame(np.random.randn(20, 5),   
                                           
                  index=time_series,
                  columns=['Column 1', 'Column 2', 'Column 3', 'Column 4', 'Column 5'])

# %%
df.iloc[:5,0:2]
# Out:
#    x  y
# 0  1  4
# 1  5  2
# 2  3  6

# %%
df[('Column 5')]
# Out:
# 2020-01-01    0.081368
# 2020-01-02    0.187512
# 2020-01-03   -0.061874
# 2020-01-04    0.252733
# 2020-01-05    0.609883
# 2020-01-06    0.109953
# 2020-01-07    1.238250
# 2020-01-08    2.346997
# 2020-01-09    0.109681
# 2020-01-10    0.496177
# 2020-01-11    0.300241
# 2020-01-12    0.611323
# 2020-01-13    0.487305
# 2020-01-14   -0.140638
# 2020-01-15   -0.363986
# 2020-01-16   -1.178403
# 2020-01-17   -0.824802
# 2020-01-18    1.188946
# 2020-01-19   -0.432062
# 2020-01-20    0.074407
# Freq: D, Name: Column 5, dtype: float64

# %%
pt=df['Column 5']
pt[time_series[2]]
# Out:
# -0.06187354119146564

# %%
a= pd.DataFrame({'x':[1,2,3],'y':[4,5,6]})
print(a)
# Out:
#    x  y
# 0  1  4
# 1  2  5
# 2  3  6

# %%
a.loc[1]={'x':5,'y':2}
print(a)
# Out:
#    x  y
# 0  1  4
# 1  5  2
# 2  3  6

# %%
time_series = pd.date_range('1/1/2020', periods=20)

df = pd.DataFrame(np.random.randn(20, 5),   
                                           
                  index=time_series,
                  columns=['Column 1', 'Column 2', 'Column 3', 'Column 4', 'Column 5'])
df
# Out:
#             Column 1  Column 2  Column 3  Column 4  Column 5
# 2020-01-01  0.455959 -0.490544 -0.586929 -0.355729 -1.192562
# 2020-01-02  0.404078  0.227757 -0.573619 -1.116051  0.776180
# 2020-01-03  1.908417  0.810479  0.851865  0.861404  1.868946
# 2020-01-04  0.195013  1.904841  0.350158 -0.295084  1.327806
# 2020-01-05 -0.400795  0.857781  0.121873 -1.099878  0.250854
# 2020-01-06  0.409351  0.313334 -0.771463 -1.064137  0.385866
# 2020-01-07 -0.238817 -0.707449  1.421894  1.016715  0.283599
# 2020-01-08 -0.729949 -0.446245  1.120282  0.401128 -0.376899
# 2020-01-09 -0.481154  1.250386 -0.176564  0.648140 -1.759913
# 2020-01-10 -0.122448 -0.572388  0.444126  0.949059 -0.322692
# 2020-01-11 -1.275625  0.039905 -0.566992 -0.270224  1.660618
# 2020-01-12 -0.677316  0.410431  0.521398  1.148628 -1.306218
# 2020-01-13 -0.460909  1.189796  0.686815  1.854798 -1.379589
# 2020-01-14  0.109028  1.131325 -1.349432 -0.236536 -0.662174
# ...

# %%
df[(df['Column 1'] < 0) & (df['Column 2'] > 0)][['Column 4', 'Column 5']]
# Out:
#             Column 4  Column 5
# 2020-01-05 -1.099878  0.250854
# 2020-01-09  0.648140 -1.759913
# 2020-01-11 -0.270224  1.660618
# 2020-01-12  1.148628 -1.306218
# 2020-01-13  1.854798 -1.379589
# 2020-01-15  0.987448 -1.252823
# 2020-01-19  0.202794  0.315893
